# %% [markdown]
# # 11 — Challenge solution
#
# Debrief only. Same kernel, after `answer` exists.
#
# Physical items, 10 percent, verified student email. Digital albums are not discounted. Applied at checkout, not after the invoice exists.

# %%
hits, text, prompt_tokens = answer(
    "What is the student discount on physical items?"
)
print("used:", [row["id"] for row in hits])
print("prompt_tokens:", prompt_tokens)
print()
print(text)
# Out:
# used: ['policy_student_discount.md', 'ticket_10_chile_student_discount.md', 'policy_international.md']
# prompt_tokens: 273
#
# A verified student email (ending in .edu or the local equivalent) gets **10 percent off physical items**.

# %%
assert hits and len(hits) >= 1, "hits should be the retrieve rows"
assert text and str(text).strip(), "text should be the generated sentence"
assert "10" in str(text), "the policy is 10 percent off physical items"
print("looks good")
# Out:
# looks good
