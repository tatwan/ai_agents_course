# %% [markdown]
# # 06 — Challenge solution
#
# Debrief only. Same kernel, after `travel_mcp.handle` exists. No model. Sydney → Madrid is 249.66 dollars, 99 minutes.

# %%
listed = travel_mcp.handle(
    {"jsonrpc": "2.0", "id": 1, "method": "tools/list", "params": {}}
)
n_tools = len(listed["result"]["tools"])

called = travel_mcp.handle(
    {
        "jsonrpc": "2.0",
        "id": 2,
        "method": "tools/call",
        "params": {
            "name": "get_flight",
            "arguments": {"from_city": "Sydney", "to_city": "Madrid"},
        },
    }
)
flight = called["result"]["content"][0]["text"]
print("n_tools:", n_tools)
print(flight)
# Out:
# n_tools: 2
# 249.66 dollars, 99 minutes

# %%
assert n_tools >= 1, "tools/list should come back with at least one tool"
assert flight and "dollar" in flight.lower(), "flight should be the text from tools/call"
print("looks good")
# Out:
# looks good
